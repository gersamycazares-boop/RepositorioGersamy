# %% [markdown]
# Una cepa de $E.coli$ tiene una tasa de crecimiento tal que un individuo se duplica cada 30 minutos.
#
#
#   Calcula en cuanto tiempo esta cepa:
#
#
# a) llenaría el volumen de la tierra
#
# b) cubriría la superficie de la tierra
#
# c) Repite el cálculo para una tasa de crecimiento
#
#         i) se duplica cada hora
#
#         ii) se duplica cada 1/4 de hora

# %%
import math as mt

# %%
from math import exp

# %%
e=5e-7
t=6.371e6

# %%
print ("Ejercicio a)")
n= ((t)**3)/((e)**3)
n
# Out:
# Ejercicio a)
# 2.0687728224880002e+39

# %%
print ("Ejercicio b)")
s= 5.10e8
b= ((s)**3)/((e)**3)
b
# Out:
# Ejercicio b)
# 1.0612080000000002e+45

# %%
print ("Ejercicio C)")

N= mt.log2(n)
N
# Out:
# Ejercicio C)
# 130.6039709282774

# %%
print ("Ejercicio i)")
N*2
# Out:
# Ejercicio i)
# 261.2079418565548

# %%
print ("Ejercicio ii)")
N/2
# Out:
# Ejercicio ii)
# 65.3019854641387

# %%
print ("tasa de crecimiento en días")
N/48
# Out:
# tasa de crecimiento en días
# 2.720916061005779
